# %%
import pandas as pd

# %%
data = pd.read_csv('Data/bom.movie_gross.csv')
data.head(10)
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
# 5                   The Twilight Saga: Eclipse   Sum.     300500000.0
# 6                                   Iron Man 2   Par.     312400000.0
# 7                                      Tangled     BV     200800000.0
# 8                                Despicable Me   Uni.     251500000.0
# 9                     How to Train Your Dragon   P/DW     217600000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010
# 5     398000000  2010
# 6     311500000  2010
# ...

# %%
# data shape
data.shape
# Out:
# (3387, 5)

# %%
# data value count
data.value_counts()
# Out:
# title                           studio    domestic_gross  foreign_gross  year
# '71                             RAtt.     1300000.0       355000         2015    1
# Solo: A Star Wars Story         BV        213800000.0     179200000      2018    1
# Sparkle (2012)                  TriS      24400000.0      240000         2012    1
# Space Dogs 3D                   EpicPics  14400.0         8300000        2012    1
# Southside with You              RAtt.     6300000.0       208000         2016    1
#                                                                                 ..
# Hubble 3D                       WB        52400000.0      21500000       2010    1
# Howl                            Osci.     617000.0        566000         2010    1
# How to be a Latin Lover         PNT       32100000.0      29700000       2017    1
# How to Train Your Dragon 2      Fox       177000000.0     444500000      2014    1
# ...

# %%
# data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
data['foreign_gross'].head(10)
# Out:
# 0    652000000
# 1    691300000
# 2    664300000
# 3    535700000
# 4    513900000
# 5    398000000
# 6    311500000
# 7    391000000
# 8    291600000
# 9    277300000
# Name: foreign_gross, dtype: object

# %%
data1 = data.sample(n = 20, random_state=1)

# %%
data1
# Out:
#                                            title  studio  domestic_gross  \
# 2070                                    Ladrones     LGF       3100000.0
# 2314  The Lady in the Car with Glasses and a Gun   Magn.          2200.0
# 2507                          Southside with You   RAtt.       6300000.0
# 893                                     Fun Size    Par.       9400000.0
# 3311                       Batti Gul Meter Chalu    Eros        250000.0
# 1301                              Black Nativity    FoxS       7000000.0
# 975                               A Late Quartet    EOne       1600000.0
# 2307                                   Club Life   Orch.          4400.0
# 2111                                5 Flights Up     FCW       1000000.0
# 1074                                 Wagner & Me    FRun         37700.0
# 462                 I Don't Know How She Does It   Wein.       9700000.0
# 2234                         The Ark of Mr. Chow      CL         54100.0
# ...

# %%
data1.duplicated().sum()
# Out:
# 0

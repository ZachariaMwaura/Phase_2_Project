# %% [markdown]
# # Cleaning & Analysis

# %% [markdown]
# -------

# %% [markdown]
# # Imports

# %%
import pandas as pd

# %% [markdown]
# ------------

# %% [markdown]
# # Read in Files

# %% [markdown]
# ## bom.movies_gross.csv

# %%
movie_gross = pd.read_csv('Data/bom.movie_gross.csv')

# %% [markdown]
# ## Directors.csv

# %%
directors = pd.read_csv('Data/Directors.csv')

# %% [markdown]
# ## rt.movie_info.tsv

# %%
movie_info = pd.read_csv('Data/rt.movie_info.tsv', delimiter='\t')

# %% [markdown]
# ## rt.reviews.tsv

# %%
reviews = pd.read_csv('Data/rt.reviews.tsv', delimiter='\t', encoding='latin1')

# %% [markdown]
# ## tmdb.movies.csv

# %%
tmdb = pd.read_csv('Data/tmdb.movies.csv')

# %% [markdown]
# ## tn.movie_budgets.csv

# %%
movie_budgets = pd.read_csv('Data/tn.movie_budgets.csv')

# %% [markdown]
# --------

# %% [markdown]
# # Display the files

# %%
movie_gross.sample(n = 10, random_state=1)
# Out:
#                                            title studio  domestic_gross  \
# 2070                                    Ladrones    LGF       3100000.0
# 2314  The Lady in the Car with Glasses and a Gun  Magn.          2200.0
# 2507                          Southside with You  RAtt.       6300000.0
# 893                                     Fun Size   Par.       9400000.0
# 3311                       Batti Gul Meter Chalu   Eros        250000.0
# 1301                              Black Nativity   FoxS       7000000.0
# 975                               A Late Quartet   EOne       1600000.0
# 2307                                   Club Life  Orch.          4400.0
# 2111                                5 Flights Up    FCW       1000000.0
# 1074                                 Wagner & Me   FRun         37700.0
#
#      foreign_gross  year
# 2070           NaN  2015
# 2314           NaN  2015
# 2507        208000  2016
# 893        2000000  2012
# 3311           NaN  2018
# ...

# %%
directors.sample(n = 10, random_state=1)
# Out:
#         Unnamed: 0   movie_id  person_id movie_id.1  \
# 369454      818377  tt3471098  nm0589182  tt3471098
# 63577       159007  tt5843670  nm3228270  tt5843670
# 238355      540412  tt4820670  nm5250505  tt4820670
# 57824       136217  tt6461888  nm0482774  tt6461888
# 52045       124544  tt1292566  nm0228542  tt1292566
# 108506      259605  tt0811021  nm0962713  tt0811021
# 270982      604064  tt2140619  nm0629658  tt2140619
# 377262      834582  tt4246346  nm6510019  tt4246346
# 136740      319496  tt1556190  nm0350099  tt1556190
# 122309      288398  tt4154664  nm1349818  tt4154664
#
#                            primary_title                    original_title  \
# 369454                     Maggie's Plan                     Maggie's Plan
# 63577                    The Stakelander                   The Stakelander
# 238355                        Love, Cecy                        Love, Cecy
# 57824                       Foolish Love                      Foolish Love
# ...

# %%
movie_info.sample(n = 20,random_state=1)
# Out:
#         id                                           synopsis rating  \
# 1279  1651  The action in this film revolves largely aroun...      R
# 1317  1702  A film about the late Oregon running legend St...  PG-13
# 177    234  After losing his crew in a fatal crash, legend...  PG-13
# 409    534  This is the true story of Rocky Dennis (Eric S...      R
# 447    586  Tali Shemesh's understated seriocomic document...     NR
# 480    627  The Kid Stays in the Picture director Brett Mo...      R
# 1424  1837  "Becoming Jane," is the story of the great, un...     PG
# 521    683  Sean Connery appears as a British publisher wh...      R
# 1425  1839  The musicians of the Buena Vista Social Club e...     PG
# 535    697  Hungarian filmmaker Bela Tarr began his career...     NR
# 987   1280  Two teenage girls embark on wild adventure aft...     NR
# 1163  1496  In the years before World War II, a Japanese c...  PG-13
# 1116  1441  A Christmas Eve in a very blended family turns...     NR
# ...

# %%
reviews.sample(n = 10, random_state=1)
# Out:
#          id                                             review rating   fresh  \
# 49929  1859  Oh, and Jet Li? I tend to agree with all of yo...    2/4  rotten
# 52363  1941                                                NaN    6/8   fresh
# 20704   833  While it may score some points as an extended ...  1.5/4  rotten
# 20318   815  Mendes' skillfully struck detachment sabotages...  2.5/4   fresh
# 8227    304  Just as Friends With Kids compares unfavorably...    NaN  rotten
# 54135  1995  It's often hard to tell what's going on -- whe...  1.5/5  rotten
# 26645  1071  While this is clearly the most controversial f...    5/5   fresh
# 50545  1881  By relegating the story to a disappointing lev...    2/4  rotten
# 53599  1976  Majestic and thought-provoking, Embrace of the...    5/5   fresh
# 6121    233  More than anything else, it looks like the sor...    NaN  rotten
#
#                    critic  top_critic                   publisher  \
# ...

# %%
tmdb.sample(n = 10, random_state=1)
# Out:
#        Unnamed: 0             genre_ids      id original_language  \
# 18847       18847   [10770, 53, 80, 18]  409393                en
# 7504         7504                  [99]  134684                en
# 14997       14997  [35, 80, 14, 27, 53]  323792                en
# 1945         1945               [10402]   51500                en
# 20969       20969    [14, 27, 9648, 53]  351460                en
# 20561       20561                    []  396106                en
# 13833       13833                    []  284008                en
# 18855       18855                  [99]  306342                sn
# 21225       21225        [18, 53, 9648]  401546                en
# 2164         2164                  [99]  157188                en
#
#                             original_title  popularity release_date  \
# 18847                     Killer Assistant       1.400   2016-04-01
# 7504          Steve Jobs: Visionary Genius       0.600   2012-07-01
# ...

# %%
movie_budgets.sample(n = 10, random_state=1)
# Out:
#       id  release_date                          movie production_budget  \
# 2706   7  Dec 31, 2008                        Admiral       $20,000,000
# 2815  16  Jul 24, 1981                       Blow Out       $18,000,000
# 3383  84  Jan 30, 2015                Project Almanac       $12,000,000
# 5077  78   Feb 1, 2013                The Gatekeepers        $1,500,000
# 3823  24  May 18, 2012                        Polisse        $8,900,000
# 3644  45  Mar 27, 2015              While We're Young       $10,000,000
# 4930  31   Oct 4, 2006                       Shortbus        $2,000,000
# 2331  32  Nov 26, 1986  Star Trek IV: The Voyage Home       $24,000,000
# 4253  54  Mar 11, 2016            10 Cloverfield Lane        $5,000,000
# 1056  57   Aug 5, 2005           The Dukes of Hazzard       $53,000,000
#
#      domestic_gross worldwide_gross
# 2706             $0     $38,585,047
# 2815    $13,747,234     $13,747,234
# 3383    $22,348,241     $32,909,437
# ...

# %% [markdown]
# -----------

# %% [markdown]
# # Cleaning

# %%
movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
# drop studio

movie_gross1 = movie_gross.drop(columns='studio')
movie_gross1
# Out:
#                                             title  domestic_gross  \
# 0                                     Toy Story 3     415000000.0
# 1                      Alice in Wonderland (2010)     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1     296000000.0
# 3                                       Inception     292600000.0
# 4                             Shrek Forever After     238700000.0
# ...                                           ...             ...
# 3382                                    The Quake          6200.0
# 3383                  Edward II (2018 re-release)          4800.0
# 3384                                     El Pacto          2500.0
# 3385                                     The Swan          2400.0
# 3386                            An Actor Prepares          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...

# %%
directors['death_year'].value_counts()
# Out:
# death_year
# 2016.0    603
# 2015.0    542
# 2018.0    482
# 2014.0    340
# 2013.0    284
# 2017.0    273
# 2012.0    260
# 2019.0    212
# 2011.0    154
# 2010.0     75
# 1985.0     32
# 2008.0     16
# 2009.0     12
# 2003.0      6
# 2006.0      5
# 2001.0      5
# 2004.0      5
# 1981.0      3
# 1944.0      3
# 2007.0      2
# 1929.0      2
# 1964.0      1
# 2002.0      1
# 1993.0      1
# 1989.0      1
# 1966.0      1
# 1950.0      1
# 1994.0      1
# Name: count, dtype: int64

# %%
directors = directors[directors['death_year'].isna()]

# %%
directors
# Out:
#         Unnamed: 0   movie_id  person_id movie_id.1  \
# 0                0  tt0285252  nm0899854  tt0285252
# 1                1  tt0285252  nm0899854  tt0285252
# 2                2  tt0285252  nm0899854  tt0285252
# 3                3  tt0285252  nm0899854  tt0285252
# 4                4  tt0285252  nm0899854  tt0285252
# ...            ...        ...        ...        ...
# 379387      838563  tt8978190  nm5176932  tt8978190
# 379388      838564  tt8978190  nm5176932  tt8978190
# 379389      838565  tt8978190  nm5176932  tt8978190
# 379390      838566  tt8992954  nm4927970  tt8992954
# 379391      838567  tt8992954  nm4927970  tt8992954
#
#                         primary_title                 original_title  \
# 0                      Life's a Beach                 Life's a Beach
# 1                      Life's a Beach                 Life's a Beach
# 2                      Life's a Beach                 Life's a Beach
# ...

# %%
directors1 = directors.drop(columns=['Unnamed: 0', 'movie_id.1', 'runtime_minutes', 'person_id.1', 'movie_id.2', 'types', 'attributes'])
directors1
# Out:
#          movie_id  person_id                  primary_title  \
# 0       tt0285252  nm0899854                 Life's a Beach
# 1       tt0285252  nm0899854                 Life's a Beach
# 2       tt0285252  nm0899854                 Life's a Beach
# 3       tt0285252  nm0899854                 Life's a Beach
# 4       tt0285252  nm0899854                 Life's a Beach
# ...           ...        ...                            ...
# 379387  tt8978190  nm5176932                 Fearing Future
# 379388  tt8978190  nm5176932                 Fearing Future
# 379389  tt8978190  nm5176932                 Fearing Future
# 379390  tt8992954  nm4927970  Rossotrevi - The red fountain
# 379391  tt8992954  nm4927970  Rossotrevi - The red fountain
#
#                        original_title  start_year                 genres  \
# 0                      Life's a Beach        2012                 Comedy
# 1                      Life's a Beach        2012                 Comedy
# ...

# %%
movie_info1 = movie_info.drop(columns=['synopsis', 'dvd_date', 'runtime', 'studio'])
movie_info1
# Out:
#         id rating                                              genre  \
# 0        1      R                Action and Adventure|Classics|Drama
# 1        3      R                  Drama|Science Fiction and Fantasy
# 2        5      R                  Drama|Musical and Performing Arts
# 3        6      R                         Drama|Mystery and Suspense
# 4        7     NR                                      Drama|Romance
# ...    ...    ...                                                ...
# 1555  1996      R   Action and Adventure|Horror|Mystery and Suspense
# 1556  1997     PG                 Comedy|Science Fiction and Fantasy
# 1557  1998      G  Classics|Comedy|Drama|Musical and Performing Arts
# 1558  1999     PG    Comedy|Drama|Kids and Family|Sports and Fitness
# 1559  2000      R  Action and Adventure|Art House and Internation...
#
#                 director                                            writer  \
# ...

# %%
movie_info.shape
# Out:
# (1560, 12)

# %%
reviews.shape
# Out:
# (54432, 8)

# %%
reviews1 = reviews.drop(columns=['critic', 'publisher', 'date'])
reviews1
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
#        top_critic
# ...

# %%
tmdb1 = tmdb.drop(columns=['Unnamed: 0', 'id'])
tmdb1
# Out:
#                  genre_ids original_language  \
# 0          [12, 14, 10751]                en
# 1      [14, 12, 16, 10751]                en
# 2            [12, 28, 878]                en
# 3          [16, 35, 10751]                en
# 4            [28, 878, 12]                en
# ...                    ...               ...
# 26512             [27, 18]                en
# 26513             [18, 53]                en
# 26514         [14, 28, 12]                en
# 26515      [10751, 12, 28]                en
# 26516             [53, 27]                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# ...

# %%
movie_budgets1 = movie_budgets.drop(columns=['id'])
movie_budgets1
# Out:
#       release_date                                        movie  \
# 0     Dec 18, 2009                                       Avatar
# 1     May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      Jun 7, 2019                                 Dark Phoenix
# 3      May 1, 2015                      Avengers: Age of Ultron
# 4     Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...            ...                                          ...
# 5777  Dec 31, 2018                                       Red 11
# 5778   Apr 2, 1999                                    Following
# 5779  Jul 13, 2005                Return to the Land of Wonders
# 5780  Sep 29, 2015                         A Plague So Pleasant
# 5781   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# ...

# %% [markdown]
# -----------

# %% [markdown]
# # Merge

# %% [markdown]
# ### Merge: movie_info with review -> movie_reviews

# %%
movie_info
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# ...

# %%
movie_reviews = pd.merge(movie_info1, reviews1, on='id')

# %%
movie_reviews
# Out:
#          id rating_x                                              genre  \
# 0         3        R                  Drama|Science Fiction and Fantasy
# 1         3        R                  Drama|Science Fiction and Fantasy
# 2         3        R                  Drama|Science Fiction and Fantasy
# 3         3        R                  Drama|Science Fiction and Fantasy
# 4         3        R                  Drama|Science Fiction and Fantasy
# ...     ...      ...                                                ...
# 54427  2000        R  Action and Adventure|Art House and Internation...
# 54428  2000        R  Action and Adventure|Art House and Internation...
# 54429  2000        R  Action and Adventure|Art House and Internation...
# 54430  2000        R  Action and Adventure|Art House and Internation...
# 54431  2000        R  Action and Adventure|Art House and Internation...
#
#                director                        writer  theater_date currency  \
# ...

# %%
movie_reviews.drop_duplicates(inplace=True)

# %%
movie_reviews.duplicated().sum()
# Out:
# 0

# %%
movie

# %% [markdown]
# -----------------
